# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y = [2,3,4,5]

plt.plot(x, y)
plt.show()

# %%
plt.bar(x,y)
plt.show()

# %%
figure = plt.figure()
axes1 = figure.add_subplot(2,2,1)
axes2 = figure.add_subplot(2,2,2)
axes3 = figure.add_subplot(2,2,3)
axes4 = figure.add_subplot(2,2,4)

# %%
import numpy as np

# %%
figure = plt.figure()
axes = figure.add_subplot(111)

x = [1,2,3,4]
y = [2,4,6,8]

x2 = np.array([1,2,3,4])
y2 = np.array([4,1,3,7])

axes.plot(x,y, color='red', linestyle='dotted', marker='o')
axes.plot(x2,y2, color='green', linestyle='dashed', marker='^')

# %%
figure = plt.figure()
axes = figure.add_subplot(111)

x = [1,3,5,7]
y = [2,4,6,8]

x2 = [2,4,6,8]
y2 = [4,4,3,6]

axes.bar(x,y, color='gray')
axes.bar(x2,y2, color='black')
plt.show()

# %%
figure = plt.figure()
axes = figure.add_subplot(111)
axes2 = axes.twinx()

x = [1,2,3,4]
y = [2,4,6,8]

x2 = [1,2,3,4]
y2 = [4,6,1,9]

axes.bar(x,y, color='gray', label='bar')
axes2.plot(x2,y2, color='black', label='plot')

axes.legend()
axes2.legend(loc=1)

plt.show()

# %%
figure = plt.figure()
axes = figure.add_subplot(111)

x = [1,2,3,4]
y = [2,4,6,8]

x2 = [1,2,3,4]
y2 = [4,6,1,9]

axes.scatter(x,y, color='gray')
axes.scatter(x2,y2, color='black')

plt.show()

# %%
from matplotlib import font_manager, rc

font_path = '/Windows/Fonts/batang.ttc'
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

figure = plt.figure()
axes = figure.add_subplot(111)

label = ['자바', '파이썬', '자바스크립트', 'HTML']
data = [1,2,5,2]

axes.pie(data, labels=label)

#plt.show()

plt.savefig('test')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5972\504162956.py in <module>
#       5 rc('font', family=font)
#       6
# ----> 7 figure = plt.figure()
#       8 axes = figure.add_subplot(111)
#       9
#
# NameError: name 'plt' is not defined

# %%
# wordcloud
import wordcloud
text = 'phthon phthon hello data data data data data'
wc = wordcloud.WordCloud()
wc.generate_from_text(text)
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
# !pip install wordcloud

# %%
text = {'python': 10, 'hello': 1, 'data': 5}
wc = wordcloud.WordCloud()
wc.generate_from_frequencies(text)
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
# wordcloud
import wordcloud
text = '파이썬 파이썬 시각화 데이터분석 오류 데이터'
font_path = '/Windows/Fonts/batang.ttc'
# 시각화 이미지 설정 : 한글폰트, 배경색
wc = wordcloud.WordCloud(font_path=font_path, background_color='pink', stopwords=['오류', '데이터'])
wc.generate_from_text(text)
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>
